# %% [markdown]
# ## CLIQUE BAIT SQL CHALLENGE
# This is a sql project created by [Danny Ma](https://www.linkedin.com/in/datawithdanny/) to help establish the foundational knowledge of sql while testing and developing logical problem skills.
# For this case study, I chose to create my database with pgAdmin and then remotely connected this to Jupyter Notebooks.
#
# To get access to this and other of Danny's projects - [8 Week SQL Challenge](https://8weeksqlchallenge.com/).
#
# Before getting started, I would also recommend installing "ipython-sql". This allows you use the 'jupyter magic' function to interact with your relational database.

# %% [markdown]
# #### Importing Libraries

# %%
import sqlalchemy
import sqlite3 as sql

# %% [markdown]
# #### Create a postgresql engine to connect to database

# %%
engine = sqlalchemy.create_engine('postgresql://postgres:password@localhost:5432/clique_bait')

# %% [markdown]
# #### Load the sql extension

# %%
# %load_ext sql

# %% [markdown]
# #### Set up the connection

# %%
# %sql $engine.url

# %% [markdown]
# #### Digital Analysis

# %% [markdown]
# ##### 1. How many users are there?

# %%
# %%sql
# SELECT COUNT(DISTINCT user_id) user_count
# FROM users;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# 1 rows affected.
# [(500,)]

# %% [markdown]
# ##### 2. How many cookies does each user have on average?

# %%
# %%sql
# SELECT ROUND((COUNT(cookie_id)*1.0 /  COUNT(DISTINCT user_id)),2) avg_cookie_per_user
# FROM users;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# 1 rows affected.
# [(Decimal('3.56'),)]

# %% [markdown]
# ##### 3. What is the unique number of visits by all users per month?

# %%
# %%sql
# SELECT EXTRACT(MONTH FROM event_time) AS month, COUNT(DISTINCT visit_id)  unique_month_visits
# FROM events
# GROUP BY month
# ORDER BY month;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# 5 rows affected.
# [(Decimal('1'), 876),
#  (Decimal('2'), 1488),
#  (Decimal('3'), 916),
#  (Decimal('4'), 248),
#  (Decimal('5'), 36)]

# %% [markdown]
# ##### 4. What is the number of events for each event type?

# %%
# %%sql
# SELECT e.event_type, ed.event_name, COUNT(e.event_type)  event_count
# FROM events e
# JOIN event_identifier ed
# ON e.event_type = ed.event_type
# GROUP BY e.event_type, ed.event_name
# ORDER BY e.event_type;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# 5 rows affected.
# [(1, 'Page View', 20928),
#  (2, 'Add to Cart', 8451),
#  (3, 'Purchase', 1777),
#  (4, 'Ad Impression', 876),
#  (5, 'Ad Click', 702)]

# %% [markdown]
# ##### 5. What is the percentage of visits which have a purchase event?

# %%
# %%sql
# WITH calc AS (
# SELECT COUNT(CASE WHEN ed.event_name = 'Purchase' THEN ed.event_name END) purch
# FROM events e
# JOIN event_identifier ed
# ON e.event_type = ed.event_type
# GROUP BY e.visit_id
#
# )
#
# SELECT  ROUND(SUM(purch)*1.0/COUNT(*)*100,2)||'%' purchases
# FROM calc;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# 1 rows affected.
# [('49.86%',)]

# %% [markdown]
# ##### 6. What is the percentage of visits which view the checkout page but do not have a purchase event?

# %%
# %%sql
# WITH calc AS (
# SELECT
# COUNT(CASE WHEN page_id = 12 THEN visit_id END) chck_out
# , COUNT(CASE WHEN page_id = 13 THEN visit_id END) purch
# FROM events e
#
# )
#
# SELECT
# ROUND(((chck_out - purch)*1.0 / chck_out)*100,2)||'%' visit_no_purchase
# FROM calc;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# 1 rows affected.
# [('15.50%',)]

# %% [markdown]
# ##### 7. What are the top 3 pages by number of views?

# %%
# %%sql
# SELECT e.page_id, ph.page_name, COUNT(e.page_id) view_count
# FROM events e
# JOIN page_hierarchy ph
# ON e.page_id = ph.page_id
# WHERE 1 = 1
# AND e.event_type = 1
# GROUP BY e.page_id, ph.page_name
# ORDER BY view_count DESC
# LIMIT 3;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# 3 rows affected.
# [(2, 'All Products', 3174), (12, 'Checkout', 2103), (1, 'Home Page', 1782)]

# %% [markdown]
# ##### 8. What is the number of views and cart adds for each product category?

# %%
# %%sql
# SELECT ph.product_category
# , COUNT(CASE WHEN ed.event_name = 'Add to Cart' THEN ed.event_name END) cart_adds
# , COUNT(CASE WHEN ed.event_name = 'Page View' THEN ed.event_name END) page_views
# FROM events e
# JOIN event_identifier ed
# ON e.event_type = ed.event_type
# JOIN page_hierarchy ph
# ON e.page_id = ph.page_id
# WHERE 1 = 1
# AND ph.product_category != 'null'
# GROUP BY ph.product_category;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# 3 rows affected.
# [('Luxury', 1870, 3032), ('Shellfish', 3792, 6204), ('Fish', 2789, 4633)]

# %% [markdown]
# ##### 9. What are the top 3 products by purchases?

# %%
# %%sql
# WITH cart AS (
# SELECT e.visit_id, e.cookie_id, e.event_type, e.page_id, ph.page_name
# FROM events e
# JOIN page_hierarchy ph
# ON e.page_id = ph.page_id
# WHERE 1 = 1
# AND ph.product_category != 'null'
# AND e.event_type = 2
# GROUP BY e.visit_id, e.cookie_id, e.event_type, e.page_id, ph.page_name
#
# )
#
# , purch AS (
# SELECT e.visit_id
# FROM events e
# JOIN page_hierarchy ph
# ON e.page_id = ph.page_id
# WHERE 1 = 1
# AND e.event_type = 3
#
# )
#
# , coupled AS (
# SELECT c.page_name
# FROM cart c
# JOIN purch p
# ON p.visit_id = c.visit_id
#
# )
#
# SELECT page_name, COUNT(page_name)
# FROM coupled
# GROUP BY page_name
# ORDER BY count DESC
# LIMIT 3;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# 3 rows affected.
# [('Lobster', 754), ('Oyster', 726), ('Crab', 719)]

# %% [markdown]
# #### Product Funnel Analysis

# %% [markdown]
# ##### Part A

# %%
# %%sql
# DROP TABLE IF EXISTS prod_performance;
# CREATE TEMP TABLE prod_performance AS
# WITH view_cart AS (
# SELECT e.visit_id, e.cookie_id, e.event_type, e.page_id
# , ph.page_name, ph.product_category
# , COUNT(CASE WHEN e.event_type = 1 THEN ph.page_name END) views
# , COUNT(CASE WHEN e.event_type = 2 THEN ph.page_name END) cart
# FROM events e
# JOIN page_hierarchy ph
# ON e.page_id = ph.page_id
# WHERE 1 = 1
# AND ph.product_category != 'null'
# GROUP BY e.visit_id, e.cookie_id, e.event_type, e.page_id, ph.page_name, ph.product_category
# ORDER BY e.visit_id, e.cookie_id
#
# )
#
# , purch AS (
# SELECT e.visit_id
# FROM events e
# JOIN page_hierarchy ph
# ON e.page_id = ph.page_id
# WHERE 1 = 1
# AND e.event_type = 3
#
# )
#
# , coupled AS (
# SELECT vc.visit_id, vc.cookie_id, vc.event_type, vc.page_id, vc.page_name
# , vc.views, vc.cart, p.visit_id visit_id1,vc.product_category
# FROM view_cart vc
# LEFT JOIN purch p
# ON vc.visit_id = p.visit_id
#
# )
#
# SELECT page_name, product_category, SUM(views) views, SUM(cart) cart
# , COUNT(CASE WHEN visit_id1 IS NOT null AND event_type = 2 THEN page_name END) purchased
# , COUNT(CASE WHEN visit_id1 IS null AND event_type = 2 THEN page_name END) abandoned
# FROM coupled
# GROUP BY page_name, product_category
# ORDER BY purchased DESC;
#
# SELECT *
# FROM prod_performance;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# Done.
# 9 rows affected.
# 9 rows affected.
# [('Lobster', 'Shellfish', Decimal('1547'), Decimal('968'), 754, 214),
#  ('Oyster', 'Shellfish', Decimal('1568'), Decimal('943'), 726, 217),
#  ('Crab', 'Shellfish', Decimal('1564'), Decimal('949'), 719, 230),
#  ('Salmon', 'Fish', Decimal('1559'), Decimal('938'), 711, 227),
#  ('Black Truffle', 'Luxury', Decimal('1469'), Decimal('924'), 707, 217),
#  ('Kingfish', 'Fish', Decimal('1559'), Decimal('920'), 707, 213),
#  ('Abalone', 'Shellfish', Decimal('1525'), Decimal('932'), 699, 233),
#  ('Tuna', 'Fish', Decimal('1515'), Decimal('931'), 697, 234),
#  ('Russian Caviar', 'Luxury', Decimal('1563'), Decimal('946'), 697, 249)]

# %% [markdown]
# ##### Part B

# %%
# %%sql
# DROP TABLE IF EXISTS product_category;
# CREATE TEMP TABLE product_category AS
# SELECT product_category, SUM(views) AS page_views, SUM(cart) AS cart_adds,
# SUM(purchased) AS purchases, SUM(abandoned) AS abandoned
# FROM prod_performance
# GROUP BY product_category;
#
# SELECT *
# FROM product_category
# ORDER BY product_category;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# Done.
# 3 rows affected.
# 3 rows affected.
# [('Fish', Decimal('4633'), Decimal('2789'), Decimal('2115'), Decimal('674')),
#  ('Luxury', Decimal('3032'), Decimal('1870'), Decimal('1404'), Decimal('466')),
#  ('Shellfish', Decimal('6204'), Decimal('3792'), Decimal('2898'), Decimal('894'))]

# %% [markdown]
# ##### i. Which product had the most views, cart adds and purchases?

# %%
# %%sql
# WITH calc AS (
# SELECT *
# , RANK() OVER (ORDER BY views DESC) most_views
# , RANK() OVER (ORDER BY cart DESC) most_cart_adds
# , RANK() OVER (ORDER BY purchased DESC) most_purchases
# FROM prod_performance
#
# )
#
# SELECT page_name, most_views, most_cart_adds, most_purchases
# FROM calc
# WHERE 1 = 1
# AND most_views = 1
# OR most_cart_adds = 1
# OR most_purchases = 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# 2 rows affected.
# [('Oyster', 1, 4, 2), ('Lobster', 6, 1, 1)]

# %% [markdown]
# - `Oyster` was the most viewed product while `Lobster` had both the most cart additions and purchases.

# %% [markdown]
# ##### ii. Which product was most likely to be abandoned?

# %%
# %%sql
# WITH calc AS (
# SELECT *
# , RANK() OVER (ORDER BY abandoned DESC) most_abandoned
# FROM prod_performance
#
# )
#
# SELECT page_name, most_abandoned
# FROM calc
# WHERE 1 = 1
# AND most_abandoned = 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# 1 rows affected.
# [('Russian Caviar', 1)]

# %% [markdown]
# - `Russian Caviar` was most likely to be abandoned with approximately `26%` added to the cart but not purchased.

# %% [markdown]
# ##### iii. Which product had the highest view to purchase percentage?

# %%
# %%sql
# SELECT page_name, ROUND((views*1.0 / purchased)*100,1)||'%' view_to_purchase
# FROM prod_performance
# GROUP BY page_name, views, purchased
# ORDER BY view_to_purchase DESC
# LIMIT 1
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# 1 rows affected.
# [('Russian Caviar', '224.2%')]

# %% [markdown]
# - `Russian Caviar` had the highest view to purchase percentage. Although it has the highest percentage, this indicates the least performance amongst other products as it was the product with the least conversion rate from views to purchase.

# %% [markdown]
# ##### iv. What is the average conversion rate from view to cart add?

# %%
# %%sql
# SELECT ROUND(AVG((cart*1.0 / views))*100,2)||'%' view_to_cart_add
# FROM prod_performance;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# 1 rows affected.
# [('60.95%',)]

# %% [markdown]
# ##### v. What is the average conversion rate from cart add to purchase?

# %%
# %%sql
# SELECT ROUND(AVG((purchased*1.0 / cart))*100,2)||'%' cart_add_to_purchase
# FROM prod_performance;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# 1 rows affected.
# [('75.93%',)]

# %% [markdown]
# #### Campaigns Analysis

# %%
# %%sql
# WITH calc AS (
# SELECT u.user_id, e.visit_id, MIN(e.event_time) visit_start_time
# , COUNT(CASE WHEN e.event_type = 1 THEN e.visit_id END) page_views
# , COUNT(CASE WHEN e.event_type = 2 THEN e.visit_id END) cart_adds
# , MAX(CASE WHEN e.event_type = 3 THEN 1 ELSE 0 END) purchase_flag
# , campaign_name
# , COUNT(CASE WHEN e.event_type = 4 THEN e.visit_id END) impressions
# , COUNT(CASE WHEN e.event_type = 5 THEN e.visit_id END) clicks
# , STRING_AGG ((CASE WHEN e.event_type = 2 THEN ph.page_name END), ', ' ORDER BY e.event_time) cart_products
# FROM users u
# JOIN events e
# ON u.cookie_id = e.cookie_id
# JOIN campaign_identifier ci
# ON e.event_time BETWEEN ci.start_date AND ci.end_date
# JOIN page_hierarchy ph
# ON e.page_id = ph.page_id
# GROUP BY u.user_id, e.visit_id, campaign_name
#
# )
#
# SELECT user_id, visit_id, visit_start_time, page_views, cart_adds
# , purchase_flag, campaign_name, impressions, clicks, cart_products
# FROM calc
# ORDER BY user_id, visit_start_time;
# Out:
#  * postgresql://postgres:***@localhost:5432/clique_bait
# 3052 rows affected.
# [(1, '0fc437', datetime.datetime(2020, 2, 4, 17, 49, 49, 602976), 10, 6, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, '
 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Tuna'),
#  (20, 'ed7061', datetime.datetime(2020, 2, 23, 22, 31, 30, 392509), 8, 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Black Truffle'),
#  (20, 'ce02d6', datetime.datetime(2020, 3, 7, 4, 7, 50, 890749), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (20, 'ae67d0', datetime.datetime(2020, 3, 7, 17, 7, 14, 935597), 8, 4, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Black Truffle, Abalone, Lobster, Crab'),
#  (20, 'af7dbb', datetime.datetime(2020, 3, 7, 18, 49, 54, 234033), 7, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Crab'),
#  (20, 'dc903f', datetime.datetime(2020, 3, 7, 20, 22, 57, 340584), 10, 7, 0, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Kingfish, Tuna, Russian Caviar, Black Truffle, Abalone, Crab'),
#  (21, 'b5f4b4', datetime.datetime(2020, 2, 14, 10, 5, 28, 444749), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (21, 'a67606', datetime.datetime(2020, 2, 14, 21, 10, 8, 838252), 5, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Lobster'),
#  (21, 'ce83bf', datetime.datetime(2020, 2, 22, 5, 22, 11, 270312), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (21, 'e07175', datetime.datetime(2020, 2, 22, 12, 4, 57, 846437), 5, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Russian Caviar'),
#  (21, '48a5f0', datetime.datetime(2020, 3, 18, 13, 44, 8, 725554), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (21, '253176', datetime.datetime(2020, 3, 18, 14, 29, 2, 578417), 8, 3, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Russian Caviar, Black Truffle, Oyster'),
#  (22, 'f6c20a', datetime.datetime(2020, 2, 8, 21, 17, 11, 74915), 7, 3, 0, 'Half Off - Treat Your Shellf(ish)', 1, 0, 'Tuna, Russian Caviar, Black Truffle'),
#  (22, '71740f', datetime.datetime(2020, 2, 8, 21, 30, 48, 985777), 11, 6, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Kingfish, Black Truffle, Abalone, Lobster, Crab, Oyster'),
#  (22, 'f124b9', datetime.datetime(2020, 2, 27, 5, 12, 7, 359658), 10, 6, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Kingfish, Tuna, Russian Caviar, Black Truffle, Abalone'),
#  (22, '9e4195', datetime.datetime(2020, 2, 27, 21, 48, 30, 608182), 11, 3, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna, Black Truffle, Crab'),
#  (22, '679b1e', datetime.datetime(2020, 3, 19, 1, 31, 10, 203892), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (22, 'd1806e', datetime.datetime(2020, 3, 19, 2, 19, 30, 400539), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (22, '2563e4', datetime.datetime(2020, 3, 19, 11, 47, 51, 280769), 8, 4, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Kingfish, Russian Caviar, Abalone, Crab'),
#  (22, '093a52', datetime.datetime(2020, 3, 19, 21, 7, 31, 926149), 8, 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Kingfish, Crab'),
#  (23, 'ed6296', datetime.datetime(2020, 1, 16, 9, 26, 44, 343546), 1, 0, 0, '25% Off - Living The Lux Life', 0, 0, None),
#  (23, 'd7fa36', datetime.datetime(2020, 1, 16, 22, 30, 1, 781000), 5, 0, 0, '25% Off - Living The Lux Life', 0, 0, None),
#  (23, '0202bb', datetime.datetime(2020, 1, 18, 10, 26, 18, 696664), 1, 0, 0, '25% Off - Living The Lux Life', 0, 0, None),
#  (23, 'a4611f', datetime.datetime(2020, 1, 18, 17, 3, 33, 985538), 7, 1, 0, '25% Off - Living The Lux Life', 0, 0, 'Black Truffle'),
#  (23, 'ac8301', datetime.datetime(2020, 2, 14, 1, 33, 28, 898783), 5, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (23, 'bf5655', datetime.datetime(2020, 2, 14, 23, 42, 40, 952651), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  
 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Kingfish, Black Truffle, Crab'),
#  (34, '5bae94', datetime.datetime(2020, 3, 22, 14, 26, 59, 905797), 8, 6, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Kingfish, Russian Caviar, Black Truffle, Abalone, Crab'),
#  (35, '6baa37', datetime.datetime(2020, 1, 22, 1, 9, 59, 482433), 7, 3, 1, '25% Off - Living The Lux Life', 0, 0, 'Salmon, Lobster, Crab'),
#  (35, '3b1710', datetime.datetime(2020, 1, 22, 14, 12, 15, 486854), 1, 0, 0, '25% Off - Living The Lux Life', 0, 0, None),
#  (35, '6decee', datetime.datetime(2020, 1, 27, 18, 11, 54, 131050), 4, 1, 1, '25% Off - Living The Lux Life', 0, 0, 'Russian Caviar'),
#  (35, '613db3', datetime.datetime(2020, 1, 27, 22, 58, 0, 640930), 1, 0, 0, '25% Off - Living The Lux Life', 0, 0, None),
#  (35, '866ff6', datetime.datetime(2020, 2, 22, 18, 37, 45, 955311), 4, 1, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna'),
#  (35, '504f3c', datetime.datetime(2020, 2, 22, 23, 21, 5, 401890), 9, 6, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Russian Caviar, Abalone, Lobster, Crab, Oyster'),
#  (35, '473c9f', datetime.datetime(2020, 3, 4, 8, 23, 36, 854497), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (35, 'cddf36', datetime.datetime(2020, 3, 4, 10, 42, 31, 354051), 7, 2, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna, Oyster'),
#  (35, 'c91b3c', datetime.datetime(2020, 3, 22, 5, 47, 8, 862364), 7, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Lobster'),
#  (35, 'bb74c2', datetime.datetime(2020, 3, 22, 7, 0, 35, 865727), 9, 3, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Kingfish, Black Truffle, Crab'),
#  (36, '6653e4', datetime.datetime(2020, 2, 14, 7, 39, 30, 257993), 6, 1, 1, 'Half Off - Treat Your Shellf(ish)', 1, 0, 'Lobster'),
#  (36, '64fca2', datetime.datetime(2020, 2, 14, 18, 8, 54, 505384), 6, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Abalone'),
#  (36, 'c6d336', datetime.datetime(2020, 2, 28, 0, 14, 30, 922201), 6, 3, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Lobster, Crab, Oyster'),
#  (36, '59ef6f', datetime.datetime(2020, 2, 28, 8, 23, 10, 55907), 10, 8, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Kingfish, Tuna, Russian Caviar, Black Truffle, Abalone, Lobster, Crab, Oyster'),
#  (36, 'a36da8', datetime.datetime(2020, 3, 4, 1, 20, 11, 115871), 5, 2, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Abalone, Lobster'),
#  (36, 'bfdf81', datetime.datetime(2020, 3, 4, 14, 29, 8, 652354), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (36, '2626e0', datetime.datetime(2020, 3, 5, 4, 4, 25, 464093), 11, 1, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Lobster'),
#  (36, '0990d9', datetime.datetime(2020, 3, 5, 20, 27, 47, 675710), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (37, 'd214e6', datetime.datetime(2020, 2, 3, 1, 15, 0, 371654), 6, 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Kingfish, Russian Caviar'),
#  (37, '21a09d', datetime.datetime(2020, 2, 3, 22, 20, 35, 76596), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (37, 'e4e256', datetime.datetime(2020, 3, 3, 18, 44, 24, 172284), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (37, '85afea', datetime.datetime(2020, 3, 3, 22, 6, 54, 492323), 6, 3, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Abalone, Lobster, Oyster'),
#  (37, '2bb5be', datetime.datetime(2020, 3, 22, 0, 20, 45, 718812), 10, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Oyster'),
#  (37, '8395ce', datetime.datetime(2020, 3, 22, 21, 18, 46, 920963), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (37, 'ac98c1', datetime.datetime(2020, 3, 23, 10, 20, 55, 620551), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (37, 'f6d227', datetime.datetime(2020, 3, 23, 19, 1, 15, 739175), 10, 4, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Kingfish, Russian Caviar, Black Truffle, Lobster'),
#  (38, 'a8fbad', datetime.datetime(2020, 2, 5, 1, 42, 51, 343451), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (38, '32b052', datetime.datetime(2020, 2, 5, 14, 27, 40, 572796), 7, 3, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Russian Caviar, Crab'),
#  (38, '46fb5e', datetime.datetime(2020, 2, 28, 1, 31, 47, 201296), 10, 7, 0, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Kingfish, Tuna, Russian Caviar, Abalone, Crab, Oyster'),
#  (38, 'a00d95', datetime.datetime(2020, 2, 28, 10, 13, 32, 543020), 7, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon'),
#  (39, 'f0e648', datetime.datetime(2020, 1, 13, 0, 46, 21, 320321), 5, 1, 1, 'BOGOF - Fishing For Compliments', 0, 0, 'Abalone'),
#  (39, '973d53', datetime.datetime(2020, 1, 13, 9, 49, 25, 457703), 1, 0, 0, 'BOGOF - Fishing For Compliments', 0, 0, None),
#  (39, '264227', datetime.datetime(2020, 1, 26, 11, 28, 38, 234146), 6, 1, 1, '25% Off - Living The Lux Life', 0, 0, 'Black Truffle'),
#  (39, 'cf26da', datetime.datetime(2020, 1, 26, 16, 49, 4, 395865), 10, 7, 1, '25% Off - Living The Lux Life', 1, 1, 'Salmon, Kingfish, Tuna, Russian Caviar, Black Truffle, Crab, Oyster'),
#  (39, '032690', datetime.datetime(2020, 2, 2, 21, 11, 37, 297959), 9, 4, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Kingfish, Tuna, Abalone'),
#  (39, 'eb170c', datetime.datetime(2020, 2, 2, 23, 53, 58, 826641), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (39, '16d4b9', datetime.datetime(2020, 2, 29, 8, 46, 40, 897529), 5, 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna, Black Truffle'),
#  (39, '9329b7', datetime.datetime(2020, 2, 29, 9, 13, 45, 88866), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (39, '613ce1', datetime.datetime(2020, 3, 21, 3, 0, 11, 392148), 7, 3, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna, Black Truffle, Crab'),
#  (39, '86518c', datetime.datetime(2020, 3, 21, 7, 0, 29, 732686), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (40, '0ffeaa', datetime.datetime(2020, 2, 7, 17, 17, 36, 6060), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (40, '8bfb23', datetime.datetime(2020, 2, 7, 22, 3, 56, 504665), 10, 5, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Russian Caviar, Abalone, Lobster, Crab'),
#  (40, 'd16e04', datetime.datetime(2020, 2, 11, 17, 7, 42, 499149), 8, 5, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Kingfish, Tuna, Abalone, Oyster'),
#  (40, '8250a8', datetime.datetime(2020, 2, 11, 22, 13, 23, 375988), 8, 5, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Russian Caviar, Abalone, Lobster, Crab'),
#  (40, '9b7fb3', datetime.datetime(2020, 2, 13, 2, 25, 6, 771684), 9, 5, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Kingfish, Tuna, Russian Caviar, Black Truffle, Abalone'),
#  (40, 'b66516', datetime.datetime(2020, 2, 13, 15, 14, 53, 821306), 8, 4, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Russian Caviar, Black Truffle, Abalone, Crab'),
#  (40, 'a2ccd2', datetime.datetime(2020, 2, 21, 8, 28, 35, 428170), 4, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (40, 'e40ce5', datetime.datetime(2020, 2, 21, 23, 2, 31, 418141), 9, 5, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, '
 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Russian Caviar, Lobster'),
#  (44, '064fcd', datetime.datetime(2020, 2, 2, 15, 10, 24, 346231), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (44, '18e348', datetime.datetime(2020, 2, 8, 0, 47, 13, 857682), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (44, '5bea27', datetime.datetime(2020, 2, 8, 21, 23, 53, 496518), 10, 2, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna, Crab'),
#  (44, '4fc3af', datetime.datetime(2020, 2, 9, 11, 40, 57, 42907), 7, 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna, Lobster'),
#  (44, '3b9fd2', datetime.datetime(2020, 2, 9, 12, 46, 52, 19921), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (44, '66a47b', datetime.datetime(2020, 2, 22, 5, 30, 20, 483802), 5, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (44, '9dc657', datetime.datetime(2020, 2, 22, 18, 56, 47, 594501), 8, 3, 1, 'Half Off - Treat Your Shellf(ish)', 1, 0, 'Black Truffle, Crab, Oyster'),
#  (44, 'f422cd', datetime.datetime(2020, 2, 22, 18, 58, 27, 930061), 7, 3, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Black Truffle, Abalone, Oyster'),
#  (44, '65389e', datetime.datetime(2020, 2, 22, 19, 0, 12, 415305), 6, 3, 1, 'Half Off - Treat Your Shellf(ish)', 1, 0, 'Russian Caviar, Abalone, Crab'),
#  (45, 'bd6a32', datetime.datetime(2020, 2, 9, 10, 12, 29, 168971), 7, 3, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Abalone, Crab, Oyster'),
#  (45, 'cf849f', datetime.datetime(2020, 2, 9, 11, 31, 50, 231946), 7, 2, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Kingfish'),
#  (45, '65e07d', datetime.datetime(2020, 2, 15, 8, 48, 37, 459277), 7, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Russian Caviar'),
#  (45, 'ae2479', datetime.datetime(2020, 2, 15, 22, 39, 37, 934874), 8, 1, 1, 'Half Off - Treat Your Shellf(ish)', 1, 0, 'Lobster'),
#  (45, 'c34613', datetime.datetime(2020, 3, 15, 21, 48, 28, 748083), 9, 6, 0, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Kingfish, Tuna, Abalone, Lobster, Crab'),
#  (45, '1a8d19', datetime.datetime(2020, 3, 15, 22, 25, 42, 487658), 7, 1, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Lobster'),
#  (46, 'd400f3', datetime.datetime(2020, 1, 25, 9, 43, 32, 258825), 6, 2, 1, '25% Off - Living The Lux Life', 0, 0, 'Tuna, Russian Caviar'),
#  (46, 'e451a8', datetime.datetime(2020, 1, 25, 20, 51, 7, 689918), 9, 6, 1, '25% Off - Living The Lux Life', 1, 1, 'Salmon, Kingfish, Black Truffle, Abalone, Crab, Oyster'),
#  (46, '2a429e', datetime.datetime(2020, 2, 9, 0, 46, 32, 181836), 7, 4, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Abalone, Lobster, Crab'),
#  (46, '6ca839', datetime.datetime(2020, 2, 9, 6, 2, 6, 510844), 6, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna'),
#  (46, '74005f', datetime.datetime(2020, 2, 17, 2, 21, 43, 898869), 7, 4, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna, Russian Caviar, Abalone, Lobster'),
#  (46, '880114', datetime.datetime(2020, 2, 17, 2, 49, 27, 116003), 7, 3, 0, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Kingfish, Russian Caviar'),
#  (47, '2b86b9', datetime.datetime(2020, 2, 20, 2, 14, 20, 715246), 9, 6, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Kingfish, Tuna, Black Truffle, Lobster, Crab'),
#  (47, 'a59fa0', datetime.datetime(2020, 2, 20, 21, 55, 32, 264200), 5, 1, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon'),
#  (47, 'd7c910', datetime.datetime(2020, 3, 13, 12, 54, 26, 898291), 7, 4, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Kingfish, Black Truffle, Oyster'),
#  (47, '49fd8a', datetime.datetime(2020, 3, 13, 16, 30, 49, 192638), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (48, '3e7fc5', datetime.datetime(2020, 2, 21, 9, 14, 25, 675661), 8, 2, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Abalone'),
#  (48, 'd2908f', datetime.datetime(2020, 2, 21, 11, 21, 37, 110047), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (48, '29e54b', datetime.datetime(2020, 2, 25, 8, 24, 8, 690462), 6, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Black Truffle'),
#  (48, 'a52659', datetime.datetime(2020, 2, 25, 14, 19, 39, 224056), 8, 6, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Kingfish, Russian Caviar, Black Truffle, Lobster, Crab'),
#  (48, '294ca6', datetime.datetime(2020, 3, 11, 10, 15, 26, 933573), 9, 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Oyster'),
#  (48, '7ccae2', datetime.datetime(2020, 3, 11, 11, 10, 21, 10735), 11, 8, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Kingfish, Tuna, Russian Caviar, Black Truffle, Abalone, Lobster, Oyster'),
#  (49, '7da3f2', datetime.datetime(2020, 1, 7, 15, 38, 30, 839708), 7, 3, 0, 'BOGOF - Fishing For Compliments', 0, 0, 'Salmon, Kingfish, Crab'),
#  (49, 'fd16c5', datetime.datetime(2020, 1, 7, 18, 40, 43, 475308), 9, 5, 1, 'BOGOF - Fishing For Compliments', 1, 1, 'Salmon, Tuna, Russian Caviar, Black Truffle, Crab'),
# ...
#  (136, 'd2dfba', datetime.datetime(2020, 1, 16, 7, 32, 23, 703333), 6, 3, 1, '25% Off - Living The Lux Life', 0, 0, 'Kingfish, Russian Caviar, Lobster'),
#  (136, 'fad2f5', datetime.datetime(2020, 1, 16, 15, 21, 11, 670483), 1, 0, 0, '25% Off - Living The Lux Life', 0, 0, None),
#  (136, '315654', datetime.datetime(2020, 1, 19, 5, 27, 1, 369606), 8, 5, 1, '25% Off - Living The Lux Life', 0, 0, 'Kingfish, Russian Caviar, Abalone, Lobster, Oyster'),
#  (136, '690dcb', datetime.datetime(2020, 1, 19, 23, 25, 39, 357087), 1, 0, 0, '25% Off - Living The Lux Life', 0, 0, None),
#  (137, '656e85', datetime.datetime(2020, 2, 6, 22, 51, 47, 846570), 7, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Kingfish'),
#  (137, '6f50a5', datetime.datetime(2020, 2, 6, 23, 11, 58, 541623), 7, 2, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Russian Caviar, Lobster'),
#  (137, '53bd3c', datetime.datetime(2020, 2, 28, 5, 10, 12, 989270), 7, 3, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna, Black Truffle, Oyster'),
#  (137, '999f36', datetime.datetime(2020, 2, 28, 8, 12, 50, 70533), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (138, '6ca2c2', datetime.datetime(2020, 1, 3, 7, 20, 12, 450787), 10, 6, 1, 'BOGOF - Fishing For Compliments', 1, 1, 'Salmon, Kingfish, Tuna, Lobster, Crab, Oyster'),
#  (138, 'f91756', datetime.datetime(2020, 1, 3, 23, 28, 36, 557858), 8, 1, 1, 'BOGOF - Fishing For Compliments', 0, 0, 'Lobster'),
#  (138, '0ecf13', datetime.datetime(2020, 1, 21, 6, 23, 10, 6767), 6, 1, 0, '25% Off - Living The Lux Life', 0, 0, 'Crab'),
#  (138, '4bc4b6', datetime.datetime(2020, 1, 21, 17, 23, 31, 17834), 11, 5, 1, '25% Off - Living The Lux Life', 1, 1, 'Kingfish, Black Truffle, Lobster, Crab, Oyster'),
#  (139, '0c6735', datetime.datetime(2020, 2, 13, 12, 35, 32, 648406), 9, 3, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna, Lobster, Oyster'),
#  (139, 'c856b5', datetime.datetime(2020, 2, 13, 19, 42, 35, 213325), 9, 6, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Kingfish, Tuna, Abalone, Lobster, Oyster'),
#  (139, '62089d', datetime.datetime(2020, 3, 11, 8, 18, 26, 440485), 7, 2, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Tuna, Black Truffle'),
#  (139, '946db3', datetime.datetime(2020, 3, 11, 9, 43, 28, 468447), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (139, '7fd020', datetime.datetime(2020, 3, 11, 13, 35, 33, 492993), 6, 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Kingfish, Black Truffle'),
#  (139, '0fbde9', datetime.datetime(2020, 3, 11, 15, 30, 51, 810924), 4, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (139, '80bee8', datetime.datetime(2020, 3, 14, 13, 35, 46, 964561), 7, 2, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Russian Caviar, Crab'),
#  (139, '180011', datetime.datetime(2020, 3, 14, 22, 38, 56, 760360), 9, 7, 0, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Kingfish, Tuna, Russian Caviar, Black Truffle, Abalone, Oyster'),
#  (139, '84dd0e', datetime.datetime(2020, 3, 15, 14, 2, 34, 402865), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (139, '53f910', datetime.datetime(2020, 3, 15, 22, 24, 41, 759382), 7, 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Russian Caviar'),
#  (140, 'b5e536', datetime.datetime(2020, 2, 21, 8, 22, 56, 855306), 5, 3, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Russian Caviar, Oyster'),
#  (140, 'bca689', datetime.datetime(2020, 2, 21, 20, 24, 21, 866687), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (140, '672c30', datetime.datetime(2020, 3, 14, 10, 35, 33, 952199), 7, 4, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Russian Caviar, Abalone, Crab'),
#  (140, '01cb19', datetime.datetime(2020, 3, 14, 14, 59, 43, 799012), 6, 1, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna'),
#  (141, '25c429', datetime.datetime(2020, 2, 25, 10, 20, 32, 856013), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (141, '941e8a', datetime.datetime(2020, 2, 25, 23, 3, 7, 932138), 10, 7, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Kingfish, Tuna, Russian Caviar, Black Truffle, Abalone, Lobster'),
#  (141, 'e9d26b', datetime.datetime(2020, 2, 27, 10, 30, 23, 76014), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (141, '5585fb', datetime.datetime(2020, 2, 27, 18, 33, 29, 543720), 6, 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Russian Caviar, Oyster'),
#  (141, 'cda374', datetime.datetime(2020, 3, 26, 6, 36, 9, 977508), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (141, '702248', datetime.datetime(2020, 3, 26, 21, 24, 18, 777050), 7, 3, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Abalone, Crab'),
#  (142, '3bab0b', datetime.datetime(2020, 2, 11, 14, 50, 26, 277838), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (142, '4d35f2', datetime.datetime(2020, 2, 11, 18, 53, 19, 869226), 8, 3, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna, Russian Caviar, Oyster'),
#  (142, '383bd1', datetime.datetime(2020, 3, 11, 0, 55, 39, 556160), 8, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Lobster'),
#  (142, 'b8ea95', datetime.datetime(2020, 3, 11, 14, 42, 51, 310703), 9, 7, 0, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Kingfish, Russian Caviar, Black Truffle, Lobster, Crab, Oyster'),
#  (143, '4b77d2', datetime.datetime(2020, 1, 17, 1, 21, 32, 365518), 11, 7, 1, '25% Off - Living The Lux Life', 1, 1, 'Salmon, Kingfish, Tuna, Black Truffle, Lobster, Crab, Oyster'),
#  (143, 'cf0b69', datetime.datetime(2020, 1, 17, 3, 45, 27, 149486), 8, 3, 0, '25% Off - Living The Lux Life', 0, 0, 'Salmon, Russian Caviar, Oyster'),
#  (143, 'd3bf2e', datetime.datetime(2020, 1, 18, 0, 13, 33, 632794), 8, 3, 0, '25% Off - Living The Lux Life', 0, 0, 'Kingfish, Black Truffle, Abalone'),
#  (143, '716f53', datetime.datetime(2020, 1, 18, 12, 38, 57, 157873), 11, 7, 1, '25% Off - Living The Lux Life', 1, 1, 'Kingfish, Tuna, Black Truffle, Abalone, Lobster, Crab, Oyster'),
#  (143, 'ea7d34', datetime.datetime(2020, 2, 9, 4, 45, 18, 928947), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (143, '615363', datetime.datetime(2020, 2, 9, 7, 18, 32, 902266), 7, 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Black Truffle, Abalone'),
#  (144, 'e9c2c4', datetime.datetime(2020, 2, 1, 2, 49, 0, 805778), 8, 5, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Kingfish, Tuna, Russian Caviar, Oyster'),
#  (144, '20d710', datetime.datetime(2020, 2, 1, 8, 16, 16, 371385), 8, 3, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Abalone, Lobster, Oyster'),
#  (144, '232e10', datetime.datetime(2020, 2, 12, 15, 15, 15, 198965), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (144, '2845ad', datetime.datetime(2020, 2, 12, 19, 26, 20, 347308), 6, 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Kingfish'),
#  (144, '5e5032', datetime.datetime(2020, 3, 6, 12, 20, 19, 997148), 4, 2, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Black Truffle, Crab'),
#  (144, '40132f', datetime.datetime(2020, 3, 6, 19, 43, 2, 133232), 6, 3, 0, 'Half Off - Treat Your Shellf(ish)', 1, 0, 'Salmon, Lobster, Oyster'),
#  (144, '20b464', datetime.datetime(2020, 3, 12, 2, 59, 2, 877258), 8, 3, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna, Russian Caviar, Lobster'),
#  (144, '4535a7', datetime.datetime(2020, 3, 12, 3, 3, 27, 667365), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (145, 'fc4ad7', datetime.datetime(2020, 1, 22, 18, 32, 34, 645887), 7, 2, 1, '25% Off - Living The Lux Life', 0, 0, 'Abalone, Oyster'),
#  (145, 'cf366a', datetime.datetime(2020, 1, 22, 20, 58, 58, 786018), 1, 0, 0, '25% Off - Living The Lux Life', 0, 0, None),
#  (145, 'fdd629', datetime.datetime(2020, 2, 3, 4, 2, 9, 125453), 5, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Black Truffle'),
#  (145, 'dc5b8f', datetime.datetime(2020, 2, 3, 4, 35, 44, 407317), 10, 6, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Tuna, Russian Caviar, Abalone, Lobster, Crab'),
#  (145, '27e573', datetime.datetime(2020, 3, 1, 10, 26, 49, 680455), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (145, '6bdd64', datetime.datetime(2020, 3, 1, 14, 6, 38, 800978), 6, 1, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Oyster'),
#  (145, 'ad79d6', datetime.datetime(2020, 3, 24, 14, 17, 2, 101852), 10, 5, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Kingfish, Tuna, Lobster, Crab'),
#  (145, 'a92327', datetime.datetime(2020, 3, 24, 19, 9, 31, 248493), 9, 5, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Tuna, Black Truffle, Abalone, Lobster, Oyster'),
#  (146, '73a060', datetime.datetime(2020, 1, 1, 12, 44, 28, 728710), 8, 3, 0, 'BOGOF - Fishing For Compliments', 0, 0, 'Abalone, Lobster, Oyster'),
#  (146, 'cdc2c2', datetime.datetime(2020, 1, 1, 22, 24, 11, 765209), 10, 7, 1, 'BOGOF - Fishing For Compliments', 1, 1, 'Salmon, Tuna, Russian Caviar, Abalone, Lobster, Crab, Oyster'),
#  (146, 'cebaf4', datetime.datetime(2020, 1, 16, 1, 29, 47, 630439), 6, 1, 0, '25% Off - Living The Lux Life', 0, 0, 'Tuna'),
#  (146, '2116b0', datetime.datetime(2020, 1, 16, 12, 17, 49, 157658), 11, 7, 1, '25% Off - Living The Lux Life', 1, 1, 'Salmon, Russian Caviar, Black Truffle, Abalone, Lobster, Crab, Oyster'),
#  (147, 'b2776f', datetime.datetime(2020, 2, 5, 9, 56, 3, 876463), 8, 4, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Kingfish, Black Truffle, Abalone, Oyster'),
#  (147, 'c0e5fe', datetime.datetime(2020, 2, 5, 16, 18, 0, 955885), 8, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon'),
#  (147, '418aab', datetime.datetime(2020, 2, 6, 4, 45, 19, 689901), 8, 1, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Russian Caviar'),
#  (147, '600c2f', datetime.datetime(2020, 2, 6, 15, 4, 56, 303254), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (147, '2eb7f9', datetime.datetime(2020, 3, 4, 5, 2, 35, 408619), 9, 2, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Crab, Oyster'),
#  (147, '539126', datetime.datetime(2020, 3, 4, 19, 28, 35, 885794), 10, 4, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Kingfish, Black Truffle, Lobster, Oyster'),
#  (148, 'f1f180', datetime.datetime(2020, 2, 3, 4, 18, 19, 987287), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (148, '94e7f4', datetime.datetime(2020, 2, 3, 5, 13, 9, 516673), 9, 2, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Kingfish, Tuna'),
#  (148, 'aecfac', datetime.datetime(2020, 2, 3, 8, 16, 6, 885594), 8, 7, 0, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Kingfish, Russian Caviar, Black Truffle, Lobster, Crab, Oyster'),
#  (148, '087ac6', datetime.datetime(2020, 2, 3, 21, 45, 10, 314851), 8, 3, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Russian Caviar, Black Truffle, Lobster'),
#  (148, '43cba6', datetime.datetime(2020, 2, 18, 13, 18, 1, 266291), 9, 4, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Black Truffle, Abalone, Crab'),
#  (148, 'dcfc83', datetime.datetime(2020, 2, 18, 23, 23, 30, 977584), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (149, '7fd65a', datetime.datetime(2020, 1, 19, 9, 52, 40, 833377), 1, 0, 0, '25% Off - Living The Lux Life', 0, 0, None),
#  (149, '21b3a1', datetime.datetime(2020, 1, 19, 17, 43, 9, 128435), 8, 3, 1, '25% Off - Living The Lux Life', 0, 0, 'Tuna, Russian Caviar, Abalone'),
#  (149, '3bd95b', datetime.datetime(2020, 2, 14, 4, 11, 10, 239016), 9, 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna, Black Truffle'),
#  (149, 'f625bd', datetime.datetime(2020, 2, 14, 12, 40, 9, 54102), 6, 3, 1, 'Half Off - Treat Your Shellf(ish)', 1, 0, 'Salmon, Russian Caviar, Abalone'),
#  (149, 'e922dd', datetime.datetime(2020, 2, 16, 5, 22, 2, 125021), 6, 1, 1, 'Half Off - Treat Your Shellf(ish)', 1, 0, 'Black Truffle'),
#  (149, 'da075f', datetime.datetime(2020, 2, 16, 11, 16, 34, 960411), 7, 4, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Kingfish, Tuna, Black Truffle'),
#  (149, 'e7ff7d', datetime.datetime(2020, 3, 14, 13, 19, 43, 439598), 8, 2, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Kingfish, Tuna'),
#  (149, '427146', datetime.datetime(2020, 3, 14, 19, 10, 39, 454024), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (150, '0fcd11', datetime.datetime(2020, 2, 12, 10, 59, 48, 381418), 6, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Black Truffle'),
#  (150, 'adfb17', datetime.datetime(2020, 2, 12, 11, 20, 12, 103176), 7, 3, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Kingfish, Russian Caviar, Crab'),
#  (150, '08ad42', datetime.datetime(2020, 2, 28, 6, 28, 51, 390638), 7, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (150, '65fa62', datetime.datetime(2020, 2, 28, 8, 42, 30, 583606), 9, 7, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Kingfish, Tuna, Black Truffle, Abalone, Lobster, Oyster'),
#  (150, 'e135b5', datetime.datetime(2020, 3, 3, 18, 30, 28, 241894), 8, 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Russian Caviar, Oyster'),
#  (150, '0e945e', datetime.datetime(2020, 3, 3, 19, 10, 22, 288836), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (150, '6fa1ba', datetime.datetime(2020, 3, 25, 9, 0, 15, 1864), 6, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Kingfish'),
#  (150, 'b3353e', datetime.datetime(2020, 3, 25, 13, 10, 55, 226735), 7, 5, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Black Truffle, Abalone, Crab, Oyster'),
#  (151, '74d9cc', datetime.datetime(2020, 2, 3, 11, 37, 36, 62093), 7, 5, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Kingfish, Tuna, Russian Caviar, Black Truffle, Lobster'),
#  (151, '68f93c', datetime.datetime(2020, 2, 3, 15, 13, 42, 317698), 8, 3, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Kingfish, Black Truffle'),
#  (151, 'd819c1', datetime.datetime(2020, 2, 22, 4, 30, 38, 779726), 5, 1, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Crab'),
#  (151, '71ac68', datetime.datetime(2020, 2, 22, 20, 18, 47, 513986), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (151, 'cfeb77', datetime.datetime(2020, 3, 5, 20, 44, 7, 894390), 10, 7, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Kingfish, Tuna, Russian Caviar, Black Truffle, Abalone, Lobster, Crab'),
#  (151, 'dac7e3', datetime.datetime(2020, 3, 5, 23, 44, 3, 441820), 9, 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Tuna, Oyster'),
#  (152, 'ceb90a', datetime.datetime(2020, 2, 27, 0, 10, 48, 123087), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (152, 'c61f82', datetime.datetime(2020, 2, 27, 23, 49, 9, 59317), 8, 4, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Kingfish, Russian Caviar, Abalone, Crab'),
#  (152, '1f0c32', datetime.datetime(2020, 3, 14, 5, 56, 49, 687036), 11, 8, 1, 'Half Off - Treat Your Shellf(ish)', 1, 1, 'Salmon, Tuna, Russian Caviar, Black Truffle, Abalone, Lobster, Crab, Oyster'),
#  (152, 'cf3cb0', datetime.datetime(2020, 3, 14, 18, 4, 15, 633705), 5, 1, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Abalone'),
#  (152, '57dce8', datetime.datetime(2020, 3, 29, 2, 54, 43, 883055), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (152, '452f03', datetime.datetime(2020, 3, 29, 19, 8, 47, 333303), 7, 2, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Abalone'),
#  (153, '3f50f0', datetime.datetime(2020, 2, 18, 6, 33, 52, 986002), 5, 1, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Lobster'),
#  (153, '9252b1', datetime.datetime(2020, 2, 18, 7, 24, 40, 196847), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (153, '9fdb3e', datetime.datetime(2020, 2, 18, 8, 29, 21, 698793), 6, 2, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Salmon, Kingfish'),
#  (153, '1691af', datetime.datetime(2020, 2, 18, 20, 23, 27, 841521), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (153, '48eb25', datetime.datetime(2020, 2, 23, 11, 8, 1, 505513), 1, 0, 0, 'Half Off - Treat Your Shellf(ish)', 0, 0, None),
#  (153, 'ff99ca', datetime.datetime(2020, 2, 23, 23, 41, 16, 181415), 6, 3, 1, 'Half Off - Treat Your Shellf(ish)', 0, 0, 'Russian Caviar, Crab, Oyster'),
#  ...]
